# %% [markdown]
# # <div style="text-align: center"> Introduction to Python
#
# ## <div style="text-align: center">Machine Learning in Python (V) - Neural Networks

# %% [markdown]
# ![logo](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Image analysis
#
# Neural networks are very often used for image or sound analysis. Normal sequential networks with connections all-to-all are used for:
# - convolutional neural networks, **CNN**, which are used for image analysis
# - recurrent neural networks, **RNN**, which are used for sound analysis
#
# Most often the fun with convolutional networks and image analysis starts with recognizing numbers. However, we will do something a little more interesting / funny - we will play with recognizing whether there is a dog or cat in the picture.
# You will find the data you need for this here: https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition
# <br><br>
# On the `data` tab of this page there are two downloadable `train.zip` and `test.zip` files. Just download the `train.zip` and then extract to the folder where this notebook is located to the `cats_vs_dogs` folder, the subfolder `train`.

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
from imports_for_ML import load_images

# %% [markdown]
# We load the names of image files:

# %%
import os

# remember to change the img_dir address!

img_dir = r'/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train'
images = os.listdir(img_dir)
images[:3]
# Out:
# ['dog.8011.jpg', 'cat.5077.jpg', 'dog.7322.jpg']

# %%
full_images = [os.path.join(img_dir, img) for img in images]

# %%
full_images[:3]
# Out:
# ['/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8011.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5077.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7322.jpg']

# %%
len(full_images)
# Out:
# 25000

# %%
full_images
# Out:
# ['/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8011.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5077.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7322.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2718.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10151.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3406.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1753.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4369.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7660.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5535.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8553.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9895.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1211.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3144.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.775.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11102.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6218.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11664.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3622.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1577.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12020.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5253.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7106.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8235.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.952.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9469.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1035.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3360.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11529.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10637.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6982.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8777.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7444.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5711.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.946.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3374.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1021.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6996.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10623.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8763.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5705.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7450.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12379.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11670.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4159.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1563.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3636.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12034.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2528.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7112.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5247.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8221.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10208.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5521.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7674.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8547.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9881.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.761.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3150.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1205.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11116.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9659.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8005.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7336.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5063.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10145.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1747.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3412.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6028.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.991.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5509.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10220.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2266.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3178.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.749.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7884.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9671.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4617.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6542.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12437.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2724.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11273.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6000.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4355.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9333.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4433.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6766.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9455.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11515.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8993.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1009.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2042.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12351.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7478.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9117.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6224.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4171.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11658.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2500.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11880.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8209.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10546.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9103.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4165.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6230.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2514.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11894.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12008.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10552.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6772.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4427.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9441.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11501.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3348.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8987.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2056.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5739.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12345.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12423.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8039.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10179.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2730.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11267.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4341.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6014.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9327.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.985.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10234.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7648.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2272.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1239.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7890.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9665.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6556.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4603.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3187.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8590.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4830.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9856.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2299.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1790.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2903.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1948.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10192.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.749.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6941.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7487.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.991.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6799.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5290.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3839.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5284.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6955.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7493.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.985.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10838.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8978.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1784.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11298.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2917.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10186.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3193.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8584.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4824.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9842.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4396.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5088.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1974.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7847.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6581.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.952.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11843.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3805.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10585.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1588.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2081.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.775.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12392.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8788.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10810.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9496.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5936.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8950.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6969.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.761.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2095.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12386.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10804.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9482.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5922.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8944.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11857.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3811.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10591.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7853.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6595.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.946.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4818.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4382.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1960.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5513.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7646.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8575.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10435.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.588.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3162.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1237.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6558.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8037.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7304.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5051.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10778.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12222.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1775.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3420.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.211.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9329.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11466.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4429.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11300.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3346.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.577.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1013.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8989.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2058.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8751.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5737.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7462.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1551.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3604.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10353.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7120.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5275.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8213.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9119.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11059.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3610.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1545.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10347.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5261.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7134.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8207.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11314.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6768.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1007.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.563.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3352.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8745.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7476.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5723.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8023.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5045.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7310.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12236.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.205.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3434.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1761.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11472.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7652.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5507.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8561.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10421.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2268.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1223.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3176.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4619.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7338.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10744.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1991.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2702.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1749.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4373.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6026.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9315.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8549.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12153.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2240.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10409.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11717.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9657.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6564.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4631.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9131.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4157.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6202.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3638.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11071.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2526.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5249.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6740.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4415.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9473.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6998.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2064.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10022.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11328.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4401.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6754.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9467.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2070.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10036.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8779.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9125.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6216.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4143.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1579.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11065.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2532.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7108.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12147.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2254.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11703.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9643.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4625.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6570.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10750.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5079.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1985.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2716.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10988.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.239.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3408.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6032.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4367.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9301.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10963.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2925.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5092.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7685.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11930.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4816.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9870.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10390.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1592.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6967.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8792.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3385.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6973.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8786.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9498.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3391.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5938.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10384.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.239.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1586.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7849.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11924.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7691.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4802.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9864.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10977.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2931.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4398.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5086.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7861.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9694.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12190.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2283.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.577.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11499.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2919.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10787.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1952.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6783.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5910.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8976.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.588.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.211.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3823.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4194.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.205.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3837.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4180.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7489.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6797.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5904.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8962.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10793.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1946.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3189.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7875.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9680.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12184.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11918.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9858.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.563.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2297.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4779.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1343.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3016.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10541.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2308.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7732.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11887.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5467.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8401.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2892.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11512.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.365.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3554.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1601.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12356.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8143.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5125.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7270.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8625.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7516.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5643.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12430.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1167.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.403.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3232.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11274.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6608.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5301.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7054.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8367.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10227.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11139.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3770.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1425.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9079.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7040.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5315.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8373.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10233.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1431.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3764.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8631.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5657.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7502.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2138.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12424.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3226.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.417.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1173.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4549.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11260.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9249.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2886.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11506.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1615.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3540.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.371.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12342.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8157.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7264.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5131.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10618.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6438.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3002.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1357.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10555.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5473.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11893.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7726.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8415.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6152.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4207.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9261.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.359.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3568.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2676.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10630.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5119.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9723.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4745.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6410.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11663.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2334.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12027.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3994.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7068.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2452.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1419.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11105.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9045.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6376.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4023.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10156.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8619.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2110.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11248.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4561.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6634.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9507.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10142.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12418.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2104.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6620.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4575.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9513.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3980.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5329.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2446.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3758.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11111.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9051.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4037.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6362.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9737.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6404.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4751.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11677.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2320.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4989.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10569.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8429.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12033.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4213.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6146.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9275.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1629.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2662.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7258.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10624.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2689.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12395.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8180.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2851.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3597.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10817.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10582.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4962.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9904.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11844.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7929.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1380.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6389.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7097.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.359.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5858.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5680.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6813.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5694.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6807.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7083.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4976.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10596.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9910.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11850.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11688.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1394.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12381.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8194.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2845.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3583.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10803.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9938.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.403.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11878.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5498.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4786.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7915.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1826.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6191.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5864.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1198.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8802.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10195.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9086.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3957.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8398.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.365.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2491.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9092.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3943.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2485.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.371.jpg',
# ...
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5843.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11936.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3970.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6392.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.199.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6820.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10795.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.628.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1197.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12182.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3958.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8397.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9089.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3780.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4789.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5497.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9937.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4951.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2862.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7280.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1829.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.25.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2876.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7294.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.31.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5483.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9923.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4945.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12196.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8383.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3794.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10781.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6834.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10959.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8819.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1183.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9534.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6607.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4552.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1168.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11474.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5894.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2123.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7519.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12230.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11739.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4010.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6345.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9076.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2461.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10427.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8368.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10341.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5468.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2307.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.628.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3019.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6423.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4776.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9710.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.23.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2645.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11312.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9252.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4234.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6161.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8158.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.37.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2651.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10018.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11306.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9246.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2889.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6175.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4220.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7729.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10355.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2313.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1358.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4762.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6437.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9704.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6351.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4004.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9062.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12169.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2475.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10433.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9520.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4546.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6613.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3229.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5880.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11460.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2137.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12224.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5658.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11705.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6379.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1416.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.172.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3743.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12141.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8354.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7067.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5332.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.833.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9508.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11448.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3201.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1154.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10756.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5670.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7525.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8616.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7243.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5116.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8170.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10030.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2679.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1632.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3567.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4208.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8432.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5454.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7701.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4992.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.614.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3025.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1370.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11063.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8426.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7715.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5440.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10369.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4986.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1364.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3031.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.600.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.9738.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11077.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5102.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7257.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8164.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10024.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.199.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3573.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1626.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.6149.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.827.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.1140.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3215.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10742.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.12218.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7531.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5664.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.8602.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.4038.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.11711.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.3757.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.166.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1402.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2449.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.12155.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8340.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5326.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.7073.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.10180.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.8817.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.5871.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.370.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2484.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.3942.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9093.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7900.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4793.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.416.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.2878.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6184.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1833.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.6190.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.1827.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.7914.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.4787.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.5499.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.11879.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/dog.9939.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.402.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.2490.jpg',
#  '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.364.jpg',
#  ...]

# %% [markdown]
# <div class="alert alert-block alert-success">
# ⚠️TASK 1 (2 min)
# <br>
#
# Using the `load_img()` function, plese display a any photo from the database (check how many photos are there, at the same time).
#
# </div>

# %% [markdown]
# Displaying a photo:

# %%
image_index = 0

# %%
load_img(full_images[image_index])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x500>

# %% [markdown]
# <div class="alert alert-block alert-success">
# ⚠️TASK 2 (4 min)
# <br>
#
# Change the code below to load another photo. Do so several times to view different photos.
# * Which index of `image_index` do the dog pictures start with?
# * Problems were reported about the datasheet we use. Check the files discussed in the comments below:
#   > Image cat.7377.jpg is labelled as a cat. However it is a person. Not a dog, not a cat. Why is it in the data?
#
#   and:
#
#   > Unless there is a cat in 1 pixel of this image I can't see, image cat.4085.jpg is clearly a dog to me.
#
# </div>

# %%
load_img(full_images[7376])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374>

# %%
load_img(full_images[4084])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=269x256>

# %% [markdown]
# Check also the picture 11222. Is it labelled as a cat or dog? Is it a cat or a dog? :)

# %%
load_img(full_images[1122])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=169x92>

# %%
full_images[11222]
# Out:
# '/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/train/cat.10335.jpg'

# %% [markdown]
# <div class="alert alert-block alert-success">
# ⚠️TASK 3 (3 min)
# <br>
#
# Each photo does not only consist of width and highth - it also consists of three layers for red (**R**), green (**G**) and blue (**B**) color. Create a matrix below from the image in the `img` variable (created in the cell above), using the `img_to_array` function (already imported above) - save the result in the `img_arr` variable. Then check the shape of the `img_arr` matrix.
#
# </div>

# %%
cat_or_dog = 'dog'
image_index = 1122
img_file = '{}.{}.{}'.format(cat_or_dog, str(image_index), 'jpg')

# %%
img = load_img(os.path.join(img_dir, img_file))

# %%
load_img(os.path.join(img_dir, img_file))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x418>

# %%
img_arr = img_to_array(img)

# %%
img_arr
# Out:
# array([[[159., 146., 112.],
#         [108.,  95.,  61.],
#         [120., 107.,  72.],
#         ...,
#         [ 75.,  50.,  46.],
#         [ 78.,  53.,  49.],
#         [143., 118., 114.]],
#
#        [[163., 150., 115.],
#         [108.,  95.,  60.],
#         [116., 103.,  68.],
#         ...,
#         [ 75.,  50.,  46.],
#         [ 79.,  54.,  50.],
#         [144., 119., 115.]],
#
#        [[167., 155., 117.],
#         [106.,  94.,  56.],
#         [110.,  98.,  60.],
#         ...,
#         [ 75.,  50.,  46.],
#         [ 79.,  54.,  50.],
#         [145., 120., 116.]],
#
#        ...,
#
#        [[111., 115., 116.],
#         [ 25.,  29.,  30.],
#         [ 27.,  31.,  32.],
#         ...,
#         [ 25.,  19.,  23.],
#         [ 14.,   8.,  12.],
#         [107., 101., 105.]],
#
#        [[ 89.,  90.,  92.],
#         [ 31.,  32.,  34.],
#         [ 25.,  26.,  28.],
#         ...,
#         [ 13.,  12.,  10.],
#         [ 21.,  20.,  18.],
#         [ 85.,  84.,  82.]],
#
#        [[215., 216., 218.],
#         [159., 160., 162.],
#         [154., 155., 157.],
#         ...,
#         [154., 153., 151.],
#         [152., 151., 149.],
#         [206., 205., 203.]]], dtype=float32)

# %%
img_arr.shape
# Out:
# (418, 500, 3)

# %% [markdown]
# Now let's display R, G and B layers separately:

# %%
fig, ax = plt.subplots(ncols=3)

# we pull out the layers one by one:
ax[0].imshow(img_arr[:, :, 0], cmap='Reds')
ax[1].imshow(img_arr[:, :, 1], cmap='Greens')
ax[2].imshow(img_arr[:, :, 2], cmap='Blues')

# we turn off the axle markings:
ax[0].axis('off')
ax[1].axis('off')
ax[2].axis('off')
# Out:
# (-0.5, 499.5, 417.5, -0.5)

# %% [markdown]
# We'll create a function for showing rgb layers

# %%
def show_rgb_layers(image, subplots_args=dict()):
    '''
    Show RGB layers of the image on separate axes.
    '''
    
    im_shape = image.shape
    
#     check if the loaded image has 3 dimensions
    assert image.ndim == 3
#     check whether the last dimension of im_shape has 3 dimensions
    assert im_shape[-1] == 3
    
#     plot rgb layers
    fig, ax = plt.subplots(ncols=3)
    for idx, layer in enumerate(['Reds', 'Greens', 'Blues']):
        ax[idx].imshow(image[:, :, idx], cmap=layer)
    
    return fig

# %%
show_rgb_layers(img_arr)

# %% [markdown]
# Please note that the training photos are in different sizes, so we have to convert them all to the same size (the network must have the same input each time). Moreover, to save time on training we will reduce the photos to the size of 50 by 50 pixels. We use the `target_size` argument in the code below to display a reduced image (we want 50 by 50 pixels):

# %%
image_index = 12639
img = load_img(full_images[image_index], target_size=(50, 50))
plt.imshow(img)
plt.title(images[image_index])
# Out:
# Text(0.5, 1.0, 'cat.9141.jpg')

# %% [markdown]
# ## Convolution
#
# In the case of neural networks, the convolution is analyzed in two dimensions. The original image is transformed by means of a convolution - each pixel is created again by multiplying by a filter (*kernel*) a given pixel and its neighbors and then adding up the obtained values:
# <img src=https://media0.giphy.com/media/XoxWy6GneEKt2/source.gif>
#
# ![img2](https://miro.medium.com/max/1280/1*C_rDXqPy0lzv9549g1i-0A.gif)
#
# For convolutional neural networks (**CNN**), neurons learn the filter weights used in the convolution.
# First, however, a few examples, to better understand the 2d convolution and its usefulness for image analysis.

# %% [markdown]
# Below we load one selected image, then average its RGB dimension to obtain a black and white image, and finally we display the image. Fill in the code below:

# %%
# We're loading a picture
image_index = 12856
test_image = img_to_array(load_img(full_images[image_index]))

# Let's average the RGB dimension
test_image_gr = test_image.mean(axis=2)

# We're displaying
plt.imshow(test_image_gr, cmap='gray')

# to get rid of the pixel indexes on the axes:
plt.axis('off')
# Out:
# (-0.5, 398.5, 498.5, -0.5)

# %% [markdown]
# ### Examples of different convolutions

# %% [markdown]
# Każdy splot to operacja na obrazie oraz filtrze, poniżej zobaczycie kilka przykładów filtrów oraz tego jaki efekt daje splecienie ich z psim pyszczkiem na obrazie.
#
# Each convolution is an operation on the image and a filter, below you will see some examples of filters and the effect of convoluting them with the dog's muzzle on the image.

# %%
# we create a filter - it's a matrix of numerical values
kernel1 = np.array([[-1, -1, -1],
                   [-1, 8, -1],
                   [-1, -1, -1]])
# we display a filter - we use imshow to display the matrix as an image
plt.imshow(kernel1)
plt.axis('off')
# Out:
# (-0.5, 2.5, 2.5, -0.5)

# %% [markdown]
# We're loading the `convolve2d` from scipy to perform the convolution.

# %%
from scipy.signal import convolve2d

# %% [markdown]
# The arguments for `convolve2d` are:
# * the first is a picture of a black and white dog's muzzle (the picture that we want to mingle with the filter)
# * the second one is the created filter (`kernel1`):

# %%
convolved_image1 = convolve2d(test_image_gr, kernel1)

plt.imshow(convolved_image1, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 400.5, 500.5, -0.5)

# %%
kernel2 = np.array([[2, -1, -1],
                    [2, -1, -1],
                    [2, -1, -1]])
plt.imshow(kernel2)
plt.axis('off')
# Out:
# (-0.5, 2.5, 2.5, -0.5)

# %%
convolved_image2 = convolve2d(test_image_gr, kernel2)

plt.imshow(convolved_image2, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 400.5, 500.5, -0.5)

# %%
kernel3 = np.array([[-1, -1, 2, 2],
                   [-1, 2, -1, -1],
                   [2, -1, -1, -1],
                   [2, -1, -1, -1]])
plt.imshow(kernel3)
plt.axis('off')
# Out:
# (-0.5, 3.5, 3.5, -0.5)

# %%
convolved_image3 = convolve2d(test_image_gr, kernel3)

plt.imshow(convolved_image3, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 401.5, 501.5, -0.5)

# %% [markdown]
# Notice that this last filter reacts quite strongly to the eye area:

# %%
# we only display high values of the last convolution
plt.imshow(convolved_image3 > 220, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 401.5, 501.5, -0.5)

# %% [markdown]
# ### A combination of filters and 2d conviolution effects

# %%
# we create a list of all filters and effects on one chart
# the first we create the chart itself, consisting of several panels
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))

# We complete the first line
ax[0, 0].imshow(kernel1)
ax[0, 1].imshow(kernel2)
ax[0, 2].imshow(kernel3)

# We complete the second line
ax[1, 0].imshow(convolved_image1, cmap='gray')
ax[1, 1].imshow(convolved_image2, cmap='gray')
ax[1, 2].imshow(convolved_image3, cmap='gray')

# We disable axle markings for all panels
for a in ax.ravel():
    a.axis('off')

# %% [markdown]
# How can convolutions be useful for image analysis? We can treat individual filters as detectors of simple features - by making a convolution we find out what is the intensity of these features in different parts of the image. The network can learn such filter weights that help in image classification.
# It is worth knowing and remembering that:
# * we are now replacing simple neurons that are connected to one another with the convolution operation. This is based on the belief that there is no need to create separate connections for the left lower part of an image and the upper right part (for example) - the dog in one and the other corner should look similar. Therefore, we want to find good detectors (filters) with which we will scan the entire image space
# * each layer of the neural network now consists not of neurons but of filters (of a certain size e.g. 3 by 3 pixels). The network learns the weights for the filters, but with a given filter we scan the entire image in the same way (we make a convolution). The convolution effect is the input for the next layer of the network.
# * In addition to the height and width dimensions, the input image also has depth (Red, Green and Blue - RGB layers), so in fact the first network layer learns the 3D filters (including height, width and colour layers).
# * Each filter is intertwined with the input image, so if the first network layer consists of 8 filters, you make 8 different convolutions and the next network layer gets 8 transformations of the original image. The dimensions of the input that the next network layer gets are in this case `height x width x 8`. Therefore, the filters that this next layer consists of have the weight of `filter height x width x filter x 8`.
# * the first convolution network layers usually learn simple detectors - lines of different orientation, subsequent layers use the detected lines to detect more complex edges, e.g. curves; the subsequent layers start to build shapes from them; and so on - the complexity of what the filters detect increases with the subsequent network layers, as the subsequent filters look for certain combinations of filters from the previous layer (so by combining two semi-circle detectors you can create a circle detector).
#
# Above we can also see a schematic diagram of neural network convolution architecture. So far we have discussed the `Conv` weave from *convolution*, but the network still includes *max-pooling* operations. Max pooling is fortunately a very simple operation reducing the dimensions of data coming out of the previous layer of the network - we divide this data into parts, each of them e.g. 3 by 3 and from each part we take only the maximum value. Example below:
# <img src=https://qph.fs.quoracdn.net/main-qimg-8afedfb2f82f279781bfefa269bc6a90>
#
# We see that for the red part the maximum value is 6, for the yellow part it is 3 etc.
# Just notice that in the first diagram in this cell at the very end (the last layers of the network) we perform the 'extension'/'expansion' operation (*flatten*) of the previous layer to a sequence of figures (like in the previous classes). The last layers of the network already operate in the classic form of neurons connected to each other. We must finally simply integrate all the properties detected by our network layers and decide what the image presents (this decision is the activity of the neuron/neurons of the last network layer).

# %% [markdown]
# ## We're loading images
# We load 10000 images, 5000 each per category (training on all would take too long).

# %%
X, y = load_images(img_dir, n_images=10000, resize=(50, 50))
# Out:
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************

# %% [markdown]
# After loading, we divide the photos into training and test photos. We have as many as 10 000 images, so we can spend only 10% (we could spend even less, even 2%) on test data, 10% of 10 000 are still 1000 images:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=23)

# %% [markdown]
# First, we read in the objects we know from Keras: Sequential and Dense:

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# For CNN-type networks we need additional layer types `Conv2D` (convolution layer), `MaxPooling2D` (previously described *max pooling*) and `Flatten` (for unrolling/unrolling the network at the end):

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten

# %% [markdown]
# We will now build a sample model to classify whether the picture shows a dog or a cat. The choice of layers and their order could be different, do not be convinced that the architecture below is most right or appropriate for this task - it is often difficult to predict in advance what exactly the network architecture will be good for the problem. Our network will consist of:
# * five hidden layers, four convolution layers and one 'dense' (all to all connection).
# * The first two convolution layers will consist of 16 filters, each 3 x 3 (plus depth). The activation function for these layers is standard `relu`.
# * after the two convolution layers we will perform a maximum pooling operation, dividing the image into segments of 3 x 3 and for each one selecting the maximum (pool_size=(3, 3))
# * then we add two more convolution layers, this time each consisting of 32 filters, each 3 x 3
# * again we use max pooling, but this time we divide the data into smaller segments - 2 by 2
# * at the end, we roll out the previous layer into one vector (*flatten*) and add a normal layer with 64 neurons
# * the output layer is just one neuron (Dense type) that tells us whether or not there's a dog in the picture, with the sigmoid activation
#
# Remember that the architecture of this network can be changed in different ways, which can translate into e.g. improved classification (the proposed project at the end of the course is e.g. playing with network parameters). Over the past few years, neural network researchers from all over the world have tested many different architectures, which have led to a better and better recognition of images and a better understanding of why some architectures can work better and others worse (and I'm talking about architectures in a slightly broader context - many ideas were studied beyond the number of layers and the order of their arrangement).

# %% [markdown]
# <div class="alert alert-block alert-success">
# ⚠️TASK 4 (6 min)
# <br>
#
# Create the model based on the information above.
#
# </div>

# %%
model = Sequential([

# we create two convolution layers, then max pooling

    Conv2D(16,(3,3), activation = 'relu' ), #16 filters/neurons, 3 by 3
    Conv2D(16,(3,3), activation = 'relu' ),
    MaxPooling2D((3,3)),
# we create next two convolution layers, then max pooling
    Conv2D(32,(3,3), activation = 'relu' ),
    Conv2D(32,(3,3), activation = 'relu' ),
    MaxPooling2D((2,2)), #for dimensionality reduction - here 2 by 2 convey even more dense information. 
    #we need double brackers because size is one argument 

# finally, we flatten all the filters to one vector and then add 64 ordinary neurons
    Flatten( input_shape = (5, 5,32)),
    Dense(64, activation = 'relu'),

# and the output neuron that says dog (1) or cat (0)
    Dense(1, activation='sigmoid')

# and compile, like always before
])
model.compile(loss = 'binary_crossentropy', optimizer  = 'adam', metrics = ['accuracy'])

# %% [markdown]
# Note that the network has a total of more than 68 thousand parameters (filter weights and connection weights) - and we have built quite a small network to modern standards.

# %% [markdown]
# Training a large network on a computer without GPU support will take a long time, so we will only set the number of epochs to `10`. In addition to the waiting time for this number of parameters (relative to the images used in training) in many epochs we can easily overtrain the network leading to great accuracy on training data, but weak on test data. The risk of overtraining is quite possible because we do not use any regularization (about this later).

# %% [markdown]
# <div class="alert alert-block alert-success">
# ⚠️TASK 5 (1 min)
# <br>
#
# Fit the model. No. of epochs = 10 (or more if you wish to wait for a longer time :) )
#
# </div>

# %%
history = model.fit(X_train, y_train, epochs = 15)
# Out:
# Epoch 1/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2850 - accuracy: 0.8786
# Epoch 2/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2440 - accuracy: 0.8972
# Epoch 3/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2209 - accuracy: 0.9119
# Epoch 4/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1788 - accuracy: 0.9280
# Epoch 5/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1913 - accuracy: 0.9231
# Epoch 6/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1380 - accuracy: 0.9428
# Epoch 7/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1440 - accuracy: 0.9438
# Epoch 8/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1008 - accuracy: 0.9599
# Epoch 9/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1170 - accuracy: 0.9566
# Epoch 10/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0942 - accuracy: 0.9647
# Epoch 11/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1145 - accuracy: 0.9573
# Epoch 12/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0862 - accuracy: 0.9691
# Epoch 13/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0981 - accuracy: 0.9634
# Epoch 14/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0926 - accuracy: 0.9659
# Epoch 15/15
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0724 - accuracy: 0.9747

# %% [markdown]
# NOTE! If for many epochs you still have a 50% correctness (e.g. `acc: 0.5001`) build the network again, i.e. restart the cell building the network (you can interrupt your notebook via `kernel -> interrupt`) and start training again. It may happen that the network gets a little 'chocked' when the weights are not properly initialized.
# Note that after a second pass through the data (epoch) the correctness is over 60% and grows relatively fast in subsequent passes. Unfortunately, this may be too good to be true - it may suggest that the network remembers examples instead of learning patterns to help identify dogs and cats.
# However, it may be that the network you are training is gradually learning and doesn't reach a speed of over 90% - a sign that your training may take a little longer and the network is learning well.
# Let's check it out - let's see how correct we are on the training and test data (if on the test data the correctness is much lower then we are dealing with overtraining i.e. *overfitting*). This time we will use a convenient method of the network `.evaluate()`, which gives us data and true answers, and which returns the cost/loss of the network and correctness (we will only be interested in correctness now):

# %%
plt.plot(history.history['accuracy'])
plt.ylabel('Accuracy')

print('Accuracy on the training data:')
print(model.evaluate(X_train, y_train)[1])

print('\nAccuracy on the test data:')
print(model.evaluate(X_test, y_test)[1])
# Out:
# Accuracy on the training data:
# 282/282 [==============================] - 2s 7ms/step - loss: 0.0406 - accuracy: 0.9872
# 0.9872221946716309
#
# Accuracy on the test data:
# 32/32 [==============================] - 0s 7ms/step - loss: 1.4215 - accuracy: 0.7120
# 0.7120000123977661

# %%
import keras

# %%
keras.models.save_model(model=model, filepath=r'/Users/kubamilcarz/My Drive/College/Sophomore/Python/Project/results', 
                           save_format='h5')

# %% [markdown]
# # Showing model seen picture

# %%
image_index = 12639
img = load_img(full_images[image_index], target_size=(50, 50))
plt.imshow(img)
plt.title(images[image_index])
# Out:
# Text(0.5, 1.0, 'cat.9141.jpg')

# %%
img_array = img_to_array(load_img(full_images[image_index], target_size=(50, 50)))

# %%
model.predict(img_array.reshape((1, 50, 50, 3))) #we use on logistic, linear, neural networks
#output is 0 (cat) or 1 (dog)
#model predict that this is cat (closer to 0)
# Out:
# 1/1 [==============================] - 0s 72ms/step
# array([[0.3419953]], dtype=float32)

# %% [markdown]
# # Unseen photo

# %%
img = load_img(r'/Users/akovbasiuk/Documents/Documents_Anna_MacBook_Pro/Classes/Python/class 10/pexels-leonardo-de-oliveira-1770918.jpg')
plt.imshow(img)

# %%
img = load_img(r'/Users/akovbasiuk/Documents/Documents_Anna_MacBook_Pro/Classes/Python/class 10/pexels-leonardo-de-oliveira-1770918.jpg', target_size=(50, 50))
plt.imshow(img)

# %%
img_array = img_to_array(img)

# %%
model.predict(img_array.reshape((1, 50, 50, 3))) #above 0.5 - dogs, below are cats
#so our model is correct
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array([[0.00534958]], dtype=float32)

# %%
img = load_img(r'/Users/akovbasiuk/Documents/Documents_Anna_MacBook_Pro/Classes/Python/class 10/pexels-ryan-horn-2318005.jpg')
plt.imshow(img)
plt.title(images[image_index])
# Out:
# Text(0.5, 1.0, 'cat.9141.jpg')

# %%
img = load_img(r'/Users/akovbasiuk/Documents/Documents_Anna_MacBook_Pro/Classes/Python/class 10/pexels-ryan-horn-2318005.jpg', target_size=(50, 50))
plt.imshow(img)

# %%
img_array = img_to_array(img)

# %%
model.predict(img_array.reshape((1, 50, 50, 3))) #says its a dog
#no matter what pics you provide them later, they will look for cats and dogs
#kinda like infants
# Out:
# 1/1 [==============================] - 0s 22ms/step
# array([[0.7668245]], dtype=float32)
